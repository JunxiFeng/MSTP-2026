# %% [markdown]
# # Project 5 Starter Notebook -- Aging and Senescence in the Human Brain
#
# **REQUIRED DAY 4/5**

# %% [markdown]
# ## Data Loading
#
# Real checkpoint, already built and verified: `/tscc/nfs/home/juf009/day4_5_shared_data/project5_senescence/project5_senescence_checkpoint.h5ad` -- 36 donors, raw counts, `.obs['age_group']` (Young/Middle/Old) and `.obs['donor']`/`.obs['sex']`/`.obs['age_at_death']` already set, plus the source's own cell-type calls at three resolutions (`cc_broadclass`, `cc_celltype`, `cc_celltype_k36`). Unlike Project 2, these annotations are included, not withheld -- checklist item 26 is directly actionable here.

# %%
import scanpy as sc

adata = sc.read_h5ad(
    "/tscc/nfs/home/juf009/day4_5_shared_data/project5_senescence/project5_senescence_checkpoint.h5ad"
)
print(adata.shape)
print(adata.obs["age_group"].value_counts())
print(adata.obs["cc_broadclass"].value_counts())
print(list(adata.obs.columns))
# Out:
# (112489, 22009)
# age_group
# Middle    41704
# Old       35721
# Young     35064
# Name: count, dtype: int64
# cc_broadclass
# Exc     46297
# Oli     23307
# Inh     17380
# Ast     10819
# OPC      8481
# Mic      4166
# End      1320
# Peri      719
# Name: count, dtype: int64
# ['bc2', 'cc_broadclass', 'cc_celltype', 'donor', 'cc_celltype_k36', 'age_group', 'age_at_death', 'sex']

# %% [markdown]
# ## Choose Your Comparison
#
# *(Scaffold only. State whether you're comparing Young vs. Old, or using all three age groups, and why -- this is checklist item 25 in miniature. If you want a neurovascular-specific angle, `cc_broadclass` includes `End` and `Peri`.)*

# %% [markdown]
# ## Quality Control
#
# *(Scaffold only -- no thresholds chosen, no cells run yet. Plot your own
# distributions first; see [04_data_loading_and_qc_guidance.md](../../lessons/04_data_loading_and_qc_guidance.md).)*
#
# ## Grouping-Variable Orientation
#
# *(Scaffold only. Confirm your independent unit and comparison groups here
# before moving on.)*
#
# ## Group-Level Comparison
#
# *(Scaffold only -- write your DEFINE statement first; see
# [05_group_level_comparison_guidance.md](../../lessons/05_group_level_comparison_guidance.md).)*
#
# ## Visualization
#
# *(Scaffold only -- load the `dataviz` skill's guidance in
# [06_visualization_capstone_guidance.md](../../lessons/06_visualization_capstone_guidance.md)
# before writing plotting code.)*
#
# ## Practice
#
# Fill in each scaffolded section above with your own analysis. Run the full
# 30-item Agent B checklist from
# [02_agent_assisted_independent_project_workflow.md](../../lessons/02_agent_assisted_independent_project_workflow.md)
# on your completed notebook before your peer review.
#
# ## Further reading
#
# - [03_project_assignments_and_datasets.md](../../lessons/03_project_assignments_and_datasets.md) -- full context for this project's dataset and locked-in comparison.
