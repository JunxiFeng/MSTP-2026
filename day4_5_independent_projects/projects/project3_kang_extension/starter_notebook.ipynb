# %% [markdown]
# # Project 3 Starter Notebook -- Kang et al. 2018, an Unexplored Cell Type
#
# **REQUIRED DAY 4/5**

# %% [markdown]
# ## Data Loading
#
# Reuses Day 3's own checkpoint directly -- no new download: `/tscc/nfs/home/juf009/day3_shared_data/kang_2018_checkpoint.h5ad` -- 24,673 cells x 15,706 genes, 8 donors, `.obs['label']` (stim/ctrl) and `.obs['cell_type']`.
#
# Day 3's worked examples already used CD14+ Monocytes and CD4 T cells -- pick a different `cell_type` for your own analysis (see [03_project_assignments_and_datasets.md](../../lessons/03_project_assignments_and_datasets.md) for real per-type counts).

# %%
import scanpy as sc

adata = sc.read_h5ad(
    "/tscc/nfs/home/juf009/day3_shared_data/kang_2018_checkpoint.h5ad"
)
print(adata.shape)
print(adata.obs["cell_type"].value_counts())
print(adata.obs["label"].value_counts())
# Out:
# (24673, 15706)
# cell_type
# CD4 T cells          11238
# CD14+ Monocytes       5697
# B cells               2651
# NK cells              1716
# CD8 T cells           1621
# FCGR3A+ Monocytes     1089
# Dendritic cells        529
# Megakaryocytes         132
# Name: count, dtype: int64
# label
# stim    12358
# ctrl    12315
# Name: count, dtype: int64

# %% [markdown]
# ## Choose Your Cell Type
#
# *(Scaffold only. State which cell type you're choosing and why, before subsetting -- this is checklist item 25 in miniature.)*

# %% [markdown]
# ## Quality Control
#
# *(Scaffold only -- no thresholds chosen, no cells run yet. Plot your own
# distributions first; see [04_data_loading_and_qc_guidance.md](../../lessons/04_data_loading_and_qc_guidance.md).)*
#
# ## Grouping-Variable Orientation
#
# *(Scaffold only. Confirm your independent unit and comparison groups here
# before moving on.)*
#
# ## Group-Level Comparison
#
# *(Scaffold only -- write your DEFINE statement first; see
# [05_group_level_comparison_guidance.md](../../lessons/05_group_level_comparison_guidance.md).)*
#
# ## Visualization
#
# *(Scaffold only -- load the `dataviz` skill's guidance in
# [06_visualization_capstone_guidance.md](../../lessons/06_visualization_capstone_guidance.md)
# before writing plotting code.)*
#
# ## Practice
#
# Fill in each scaffolded section above with your own analysis. Run the full
# 30-item Agent B checklist from
# [02_agent_assisted_independent_project_workflow.md](../../lessons/02_agent_assisted_independent_project_workflow.md)
# on your completed notebook before your peer review.
#
# ## Further reading
#
# - [03_project_assignments_and_datasets.md](../../lessons/03_project_assignments_and_datasets.md) -- full context for this project's dataset and locked-in comparison.
