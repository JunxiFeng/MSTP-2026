# %% [markdown]
# # Project 2 Starter Notebook -- Pediatric Osteosarcoma
#
# **REQUIRED DAY 4/5**

# %% [markdown]
# ## Data Loading
#
# Real checkpoint, already built and verified: `/tscc/nfs/home/juf009/day4_5_shared_data/project2_sarcoma/project2_sarcoma_checkpoint.h5ad` -- 27 samples, raw counts, `.obs['primary_or_metastasis']` already set. This checkpoint deliberately excludes the source's own pre-computed cell-type/doublet/CNV annotations (checklist item 26) -- if you cluster or annotate, it's your own.
#
# A trimmed per-sample metadata file is also available: `/tscc/nfs/home/juf009/day4_5_shared_data/project2_sarcoma/single-cell_metadata_trimmed.tsv` (`disease_timing`, `tissue_location`).

# %%
import scanpy as sc

adata = sc.read_h5ad(
    "/tscc/nfs/home/juf009/day4_5_shared_data/project2_sarcoma/project2_sarcoma_checkpoint.h5ad"
)
print(adata.shape)
print(adata.obs["primary_or_metastasis"].value_counts())
print(list(adata.obs.columns))
# Out:
# (167180, 60319)
# primary_or_metastasis
# Primary       112108
# Metastasis     55072
# Name: count, dtype: int64
# ['sum', 'detected', 'subsets_mito_sum', 'subsets_mito_detected', 'subsets_mito_percent', 'total', 'prob_compromised', 'miQC_pass', 'scDblFinder_class', 'scDblFinder_score', 'scpca_filter', 'library_id', 'sample_id', 'participant_id', 'submitter_id', 'sex', 'diagnosis', 'subdiagnosis', 'tissue_location', 'disease_timing', 'primary_or_metastasis', 'sample_key']

# %% [markdown]
# ## Quality Control
#
# *(Scaffold only -- no thresholds chosen, no cells run yet. Plot your own
# distributions first; see [04_data_loading_and_qc_guidance.md](../../lessons/04_data_loading_and_qc_guidance.md).)*
#
# ## Grouping-Variable Orientation
#
# *(Scaffold only. Confirm your independent unit and comparison groups here
# before moving on.)*
#
# ## Group-Level Comparison
#
# *(Scaffold only -- write your DEFINE statement first; see
# [05_group_level_comparison_guidance.md](../../lessons/05_group_level_comparison_guidance.md).)*
#
# ## Visualization
#
# *(Scaffold only -- load the `dataviz` skill's guidance in
# [06_visualization_capstone_guidance.md](../../lessons/06_visualization_capstone_guidance.md)
# before writing plotting code.)*
#
# ## Practice
#
# Fill in each scaffolded section above with your own analysis. Run the full
# 30-item Agent B checklist from
# [02_agent_assisted_independent_project_workflow.md](../../lessons/02_agent_assisted_independent_project_workflow.md)
# on your completed notebook before your peer review.
#
# ## Further reading
#
# - [03_project_assignments_and_datasets.md](../../lessons/03_project_assignments_and_datasets.md) -- full context for this project's dataset and locked-in comparison.
